# %% [markdown]
# # Text Classification Using the Stanford SST Sentiment Dataset
#
# Projects in Advanced Machine Learning

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# 1) Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare==0.0.189
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: aimodelshare==0.0.189 in /usr/local/lib/python3.9/dist-packages (0.0.189)
# Requirement already satisfied: Pympler==0.9 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (0.9)
# Requirement already satisfied: onnx==1.12.0 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.12.0)
# Requirement already satisfied: pydot==1.3.0 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.3.0)
# Requirement already satisfied: scikit-learn==1.2.1 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.2.1)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.6.3)
# Requirement already satisfied: importlib-resources==5.10.0 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (5.10.0)
# Requirement already satisfied: psutil>=5.9.1 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (5.9.4)
# Requirement already satisfied: botocore==1.29.82 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.29.82)
# Requirement already satisfied: onnxconverter-common>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.13.0)
# Requirement already satisfied: skl2onnx>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.14.0)
# Requirement already satisfied: seaborn>=0.11.2 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (0.12.2)
# Requirement already satisfied: pathlib>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.0.1)
# Requirement already satisfied: tf2onnx in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.14.0)
# Requirement already satisfied: onnxruntime>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.14.1)
# Requirement already satisfied: boto3==1.26.69 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.26.69)
# Requirement already satisfied: docker==5.0.0 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (5.0.0)
# Requirement already satisfied: onnxmltools>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.11.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (2022.10.31)
# Requirement already satisfied: wget==3.2 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (3.2)
# Requirement already satisfied: keras2onnx>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.7.0)
# Requirement already satisfied: scipy==1.7.0 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.7.0)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (2.0.0+cu118)
# Requirement already satisfied: shortuuid>=1.0.8 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (1.0.11)
# Requirement already satisfied: tensorflow==2.9.2 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (2.9.2)
# Requirement already satisfied: protobuf==3.19.6 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (3.19.6)
# Requirement already satisfied: PyJWT>=2.4.0 in /usr/local/lib/python3.9/dist-packages (from aimodelshare==0.0.189) (2.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse==1.6.3->aimodelshare==0.0.189) (0.40.0)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from astunparse==1.6.3->aimodelshare==0.0.189) (1.16.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from boto3==1.26.69->aimodelshare==0.0.189) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from boto3==1.26.69->aimodelshare==0.0.189) (0.6.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.9/dist-packages (from botocore==1.29.82->aimodelshare==0.0.189) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.9/dist-packages (from botocore==1.29.82->aimodelshare==0.0.189) (1.26.15)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /usr/local/lib/python3.9/dist-packages (from docker==5.0.0->aimodelshare==0.0.189) (2.27.1)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.9/dist-packages (from docker==5.0.0->aimodelshare==0.0.189) (1.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources==5.10.0->aimodelshare==0.0.189) (3.15.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.9/dist-packages (from onnx==1.12.0->aimodelshare==0.0.189) (1.22.4)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.9/dist-packages (from onnx==1.12.0->aimodelshare==0.0.189) (4.5.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.9/dist-packages (from pydot==1.3.0->aimodelshare==0.0.189) (3.0.9)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.2.1->aimodelshare==0.0.189) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.2.1->aimodelshare==0.0.189) (3.1.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (2.9.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (2.9.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (67.6.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (1.53.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (2.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (0.32.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (1.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (16.0.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (0.4.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (1.12)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare==0.0.189) (2.9.0)
# Requirement already satisfied: fire in /usr/local/lib/python3.9/dist-packages (from keras2onnx>=1.7.0->aimodelshare==0.0.189) (0.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from onnxruntime>=1.7.0->aimodelshare==0.0.189) (1.11.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.9/dist-packages (from onnxruntime>=1.7.0->aimodelshare==0.0.189) (15.0.1)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.9/dist-packages (from seaborn>=0.11.2->aimodelshare==0.0.189) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.9/dist-packages (from seaborn>=0.11.2->aimodelshare==0.0.189) (3.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.8.1->aimodelshare==0.0.189) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.8.1->aimodelshare==0.0.189) (3.11.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.8.1->aimodelshare==0.0.189) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.8.1->aimodelshare==0.0.189) (3.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.8.1->aimodelshare==0.0.189) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.8.1->aimodelshare==0.0.189) (16.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare==0.0.189) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare==0.0.189) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare==0.0.189) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare==0.0.189) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare==0.0.189) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25->seaborn>=0.11.2->aimodelshare==0.0.189) (2022.7.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare==0.0.189) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare==0.0.189) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare==0.0.189) (3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (2.17.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (0.6.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.9/dist-packages (from coloredlogs->onnxruntime>=1.7.0->aimodelshare==0.0.189) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.8.1->aimodelshare==0.0.189) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->onnxruntime>=1.7.0->aimodelshare==0.0.189) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (6.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare==0.0.189) (3.2.2)

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/sst2_competition_data-repository:latest')
# Out:
# Downloading [=============================================>   ]
#
# Data downloaded successfully.

# %%
# Set up X_train, X_test, and y_train_labels objects
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=Warning)

X_train=pd.read_csv("sst2_competition_data/X_train.csv", squeeze=True)
X_test=pd.read_csv("sst2_competition_data/X_test.csv", squeeze=True)

y_train_labels=pd.read_csv("sst2_competition_data/y_train_labels.csv", squeeze=True)

# ohe encode Y data
y_train = pd.get_dummies(y_train_labels)

X_train.head()
# Out:
# 0    The Rock is destined to be the 21st Century 's...
# 1    The gorgeously elaborate continuation of `` Th...
# 2    Singer/composer Bryan Adams contributes a slew...
# 3                 Yet the act is still charming here .
# 4    Whether or not you 're enlightened by any of D...
# Name: text, dtype: object

# %%
print(X_train[1])
# Out:
# The gorgeously elaborate continuation of `` The Lord of the Rings '' trilogy is so huge that a column of words can not adequately describe co-writer/director Peter Jackson 's expanded vision of J.R.R. Tolkien 's Middle-earth .

# %%
print(X_train[2])
# Out:
# Singer/composer Bryan Adams contributes a slew of songs -- a few potential hits , a few more simply intrusive to the story -- but the whole package certainly captures the intended , er , spirit of the piece .

# %%
print("X_train size:", len(X_train))
print("X_test size:", len(X_test))
print("total number of reviews:", len(X_train)+len(X_test))
print("y_train size:", len(y_train))
# Out:
# X_train size: 6920
# X_test size: 1821
# total number of reviews: 8741
# y_train size: 6920

# %%
# Take a look at the y_train_labels
import numpy as np
from collections import Counter

Counter(y_train_labels)
# Out:
# Counter({'Positive': 3610, 'Negative': 3310})

# %% [markdown]
# # **Discuss the dataset in general terms and describe why building a predictive model using this data might be practically useful.  Who could benefit from a model like this? Explain.**

# %% [markdown]
# This dataset is called Stanford Sentiment Treebank - Movie Review Classification. In total, there are 8741 reviews, and 6920 labels.
#
# There are three seperate datasets in the whole dataset:
# 1. X_train: there are 6920 reviews in X_train.
# 2. X_test: there are 1921 reviews in X_test.
# 3. Y_train_labels: y_train_labels contains 6920 labels of the 6920 reviews in X_train. There are 2 kinds of labels, positive and negative. There are 3610 positive labels and 3310 negative labels.
#
# Here, I will build predictive model using this dataset. Building a label prediction model for a movie review classification dataset would be useful for several reasons:
#
# * Automation: A label prediction model can automate the task of classifying movie reviews, saving time and effort compared to manual classification. This can be particularly useful when dealing with large datasets that would be impractical to classify manually.
#
# * Consistency: A label prediction model can provide consistent and standardized classification, reducing the potential for human error and bias.
#
# * Insights: By analyzing the model's predictions, we can gain insights into the factors that contribute to positive or negative reviews. This can help movie studios and filmmakers to better understand their audiences and improve their products.
#
# * Recommendation systems: A label prediction model can be integrated into a recommendation system to suggest movies to users based on their preferences. This can improve the user experience and increase user engagement.
#
# Overall, building a label prediction model for a movie review classification dataset can help to improve efficiency, consistency, and insights, leading to better decision-making and user experiences.
#
# The model can be useful for researchers and analysts who are interested in understanding the patterns and trends in movie reviews. They can use the model to identify the most common positive and negative sentiments in the reviews and track how these sentiments change over time.

# %% [markdown]
# 2) Preprocess data using keras tokenizer / Write and Save Preprocessor function

# %%
# This preprocessor function makes use of the tf.keras tokenizer

from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences
import numpy as np

# Build vocabulary from training text data
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X_train)

word_index = tokenizer.word_index

# preprocessor tokenizes words and makes sure all documents have the same length
def preprocessor(data, maxlen=40, max_words=10000):

    sequences = tokenizer.texts_to_sequences(data)

    word_index = tokenizer.word_index
    X = pad_sequences(sequences, maxlen=maxlen)

    return X

print(preprocessor(X_train).shape)
print(preprocessor(X_test).shape)
# Out:
# (6920, 40)
# (1821, 40)

# %% [markdown]
# # **Run at least three prediction models to try to predict the SST sentiment dataset well.**

# %% [markdown]
# *   Use an Embedding layer and LSTM layers in at least one model

# %% [markdown]
# * Use an Embedding layer and Conv1d layers in at least one model

# %% [markdown]
# * Use transfer learning with glove embeddings for at least one of these models

# %%
# Model 1: Embedding layer and LSTM layers

from tensorflow.keras.layers import Dense, Embedding, LSTM, Flatten
from tensorflow.keras.models import Sequential

model1 = Sequential()
model1.add(Embedding(10000, 16, input_length=40))
model1.add(LSTM(32, return_sequences=True, dropout=0.2))
model1.add(LSTM(32, dropout=0.2))
model1.add(Flatten())
model1.add(Dense(2, activation='softmax'))

model1.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model1.fit(preprocessor(X_train), y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# Epoch 1/10
# 173/173 [==============================] - 14s 53ms/step - loss: 0.6530 - acc: 0.6203 - val_loss: 0.8892 - val_acc: 0.2197
# Epoch 2/10
# 173/173 [==============================] - 6s 36ms/step - loss: 0.5025 - acc: 0.7545 - val_loss: 0.7371 - val_acc: 0.5990
# Epoch 3/10
# 173/173 [==============================] - 10s 57ms/step - loss: 0.3844 - acc: 0.8293 - val_loss: 0.4997 - val_acc: 0.7847
# Epoch 4/10
# 173/173 [==============================] - 6s 35ms/step - loss: 0.3139 - acc: 0.8672 - val_loss: 0.7429 - val_acc: 0.6857
# Epoch 5/10
# 173/173 [==============================] - 7s 43ms/step - loss: 0.2696 - acc: 0.8882 - val_loss: 0.6122 - val_acc: 0.7355
# Epoch 6/10
# 173/173 [==============================] - 8s 49ms/step - loss: 0.2313 - acc: 0.9050 - val_loss: 0.6220 - val_acc: 0.7435
# Epoch 7/10
# 173/173 [==============================] - 6s 35ms/step - loss: 0.2015 - acc: 0.9200 - val_loss: 0.6409 - val_acc: 0.7139
# Epoch 8/10
# 173/173 [==============================] - 9s 51ms/step - loss: 0.1802 - acc: 0.9285 - val_loss: 0.5766 - val_acc: 0.7522
# Epoch 9/10
# 173/173 [==============================] - 7s 41ms/step - loss: 0.1667 - acc: 0.9355 - val_loss: 0.6492 - val_acc: 0.7355
# Epoch 10/10
# 173/173 [==============================] - 7s 39ms/step - loss: 0.1454 - acc: 0.9451 - val_loss: 0.6346 - val_acc: 0.7392

# %%
# Model 2: Embedding layer and Conv1d layers

from tensorflow.keras.layers import Dense, Embedding, Conv1D, GlobalMaxPooling1D

model2 = Sequential()
model2.add(Embedding(10000, 32, input_length=40))
model2.add(Conv1D(32, 7, activation='relu'))
model2.add(GlobalMaxPooling1D())
model2.add(Dense(2, activation='softmax'))

model2.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history2 = model2.fit(preprocessor(X_train), y_train, epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10
# 44/44 [==============================] - 2s 22ms/step - loss: 0.6678 - acc: 0.6136 - val_loss: 0.8789 - val_acc: 0.1488
# Epoch 2/10
# 44/44 [==============================] - 1s 16ms/step - loss: 0.6410 - acc: 0.6154 - val_loss: 0.8085 - val_acc: 0.1749
# Epoch 3/10
# 44/44 [==============================] - 1s 17ms/step - loss: 0.5795 - acc: 0.6898 - val_loss: 0.7676 - val_acc: 0.3829
# Epoch 4/10
# 44/44 [==============================] - 1s 18ms/step - loss: 0.4810 - acc: 0.8046 - val_loss: 0.7358 - val_acc: 0.5145
# Epoch 5/10
# 44/44 [==============================] - 1s 16ms/step - loss: 0.3791 - acc: 0.8598 - val_loss: 0.5624 - val_acc: 0.7204
# Epoch 6/10
# 44/44 [==============================] - 1s 17ms/step - loss: 0.2939 - acc: 0.8990 - val_loss: 0.5729 - val_acc: 0.7110
# Epoch 7/10
# 44/44 [==============================] - 1s 16ms/step - loss: 0.2310 - acc: 0.9203 - val_loss: 0.6381 - val_acc: 0.6799
# Epoch 8/10
# 44/44 [==============================] - 1s 17ms/step - loss: 0.1826 - acc: 0.9352 - val_loss: 0.5528 - val_acc: 0.7457
# Epoch 9/10
# 44/44 [==============================] - 1s 17ms/step - loss: 0.1451 - acc: 0.9512 - val_loss: 0.6403 - val_acc: 0.7240
# Epoch 10/10
# 44/44 [==============================] - 1s 17ms/step - loss: 0.1144 - acc: 0.9637 - val_loss: 0.6321 - val_acc: 0.7421

# %%
# Model 3: transfer learning with glove embeddings

# Download Glove embedding matrix weights
! wget http://nlp.stanford.edu/data/wordvecs/glove.6B.zip

! unzip glove.6B.zip
# Out:
# --2023-04-13 02:15:00--  http://nlp.stanford.edu/data/wordvecs/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/wordvecs/glove.6B.zip [following]
# --2023-04-13 02:15:00--  https://nlp.stanford.edu/data/wordvecs/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/wordvecs/glove.6B.zip [following]
# --2023-04-13 02:15:00--  https://downloads.cs.stanford.edu/nlp/data/wordvecs/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182753 (822M) [application/zip]
# Saving to: ‘glove.6B.zip.2’
#
# glove.6B.zip.2        1%[                    ]  15.71M  39.1MB/s               ^C
# Archive:  glove.6B.zip
# replace glove.6B.100d.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace glove.6B.200d.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace glove.6B.300d.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace glove.6B.50d.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
# Extract embedding data for 100 feature embedding matrix
import os
glove_dir = os.getcwd()

embeddings_index = {}
f = open(os.path.join(glove_dir, 'glove.6B.100d.txt'))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))

# Build embedding matrix
embedding_dim = 100 # change if you use txt files using larger number of features

max_words = 10000

embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if i < max_words:
        if embedding_vector is not None:
            # Words not found in embedding index will be all-zeros.
            embedding_matrix[i] = embedding_vector
# Out:
# Found 400001 word vectors.

# %%
model3 = Sequential()
model3.add(Embedding(max_words, embedding_dim, input_length=40))
model3.add(Flatten())
model3.add(Dense(32, activation='relu'))
model3.add(Dense(2, activation='softmax'))
model3.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_23 (Embedding)    (None, 40, 100)           1000000
#
#  flatten_16 (Flatten)        (None, 4000)              0
#
#  dense_30 (Dense)            (None, 32)                128032
#
#  dense_31 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 1,128,098
# Trainable params: 1,128,098
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set weights for the Embedding layer
model3.layers[0].set_weights([embedding_matrix])
model3.layers[0].trainable = False

model3.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

history3 = model3.fit(preprocessor(X_train), y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)

model3.save_weights('pre_trained_glove_model.h5')
# Out:
# Epoch 1/10
# 173/173 [==============================] - 1s 5ms/step - loss: 0.6230 - acc: 0.6492 - val_loss: 0.7760 - val_acc: 0.5275
# Epoch 2/10
# 173/173 [==============================] - 1s 7ms/step - loss: 0.5053 - acc: 0.7507 - val_loss: 0.6329 - val_acc: 0.6850
# Epoch 3/10
# 173/173 [==============================] - 1s 7ms/step - loss: 0.4237 - acc: 0.8058 - val_loss: 0.6373 - val_acc: 0.7059
# Epoch 4/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.3577 - acc: 0.8463 - val_loss: 0.8645 - val_acc: 0.5723
# Epoch 5/10
# 173/173 [==============================] - 1s 8ms/step - loss: 0.2921 - acc: 0.8819 - val_loss: 0.9589 - val_acc: 0.5947
# Epoch 6/10
# 173/173 [==============================] - 1s 8ms/step - loss: 0.2332 - acc: 0.9140 - val_loss: 0.6431 - val_acc: 0.7355
# Epoch 7/10
# 173/173 [==============================] - 1s 8ms/step - loss: 0.1819 - acc: 0.9366 - val_loss: 1.0513 - val_acc: 0.6149
# Epoch 8/10
# 173/173 [==============================] - 1s 8ms/step - loss: 0.1373 - acc: 0.9603 - val_loss: 1.4692 - val_acc: 0.5477
# Epoch 9/10
# 173/173 [==============================] - 1s 5ms/step - loss: 0.1037 - acc: 0.9711 - val_loss: 1.0622 - val_acc: 0.6597
# Epoch 10/10
# 173/173 [==============================] - 1s 5ms/step - loss: 0.0754 - acc: 0.9836 - val_loss: 1.0959 - val_acc: 0.6864

# %% [markdown]
# # **Discuss which models performed better and point out relevant hyper-parameter values for successful models.**

# %% [markdown]
# Model1 is #10 on leader board.
#
# Model2 is #3 on leader board.
#
# Model3 is #39 on leader board.
#
# Model2 performs better than the others. The relevant hyper-parameter values for model2 are:
#
#
# *   **Embedding Dimension**: The embedding layer in the model defines the dimension of the dense embedding vectors used to represent each word in the input text. In this case, the embedding dimension is set to 32.
#
# *   **Filter Size**: The Conv1D layer in the model uses a kernel of size 7 to perform convolution on the input sequence.
#
# *   **Number of Filters**: The Conv1D layer in the model uses 32 filters to generate 32 feature maps.
#
# *   **Pooling Method**: The GlobalMaxPooling1D layer in the model performs global max pooling on the feature maps generated by the Conv1D layer.
#
# *   **Number of Hidden Units**: The Dense layer in the model has 2 hidden units.
#
# *   **Learning Rate**: The learning rate is a hyperparameter that controls the step size of the optimizer during training. In this case, the optimizer is RMSprop, which has a default learning rate of 0.001.
#
# *   **Batch Size**: The batch size is the number of samples that are processed before the model is updated during training. In this case, the batch size is set to 128.
#
# *   **Number of Epochs**: The number of epochs is the number of times the model is trained on the entire dataset. In this case, the model is trained for 10 epochs.

# %% [markdown]
# # **Submit your best three models to the leader board for the SST Model Share competition.**

# %%
# Save preprocessor
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl="https://rlxjxnoql9.execute-api.us-east-1.amazonaws.com/prod/m" #This is the unique rest api that powers this Movie Review Playground

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model1 = model_to_onnx(model1, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model1.onnx", "wb") as f:
    f.write(onnx_model1.SerializeToString())

# %%
# Submit the best three models to the leader board

#Submit Model 1: 

#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model1.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model1.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 57/57 [==============================] - 1s 15ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 70
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_e9ef9_row0_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 81.8%, transparent 81.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_e9ef9_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 81.8%, transparent 81.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_e9ef9_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 81.8%, transparent 81.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_e9ef9_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 81.8%, transparent 81.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_e9ef9_row0_col4, #T_e9ef9_row0_col5, #T_e9ef9_row0_col6, #T_e9ef9_row0_col7, #T_e9ef9_row0_col8, #T_e9ef9_row0_col9, #T_e9ef9_row0_col10, #T_e9ef9_row0_col11, #T_e9ef9_row0_col12, #T_e9ef9_row0_col13, #T_e9ef9_row0_col14, #T_e9ef9_row0_col15, #T_e9ef9_row0_col16, #T_e9ef9_row0_col17, #T_e9ef9_row0_col18, #T_e9ef9_row0_col19, #T_e9ef9_row0_col20, #T_e9ef9_row0_col21, #T_e9ef9_row0_col22, #T_e9ef9_row0_col23, #T_e9ef9_row0_col24, #T_e9ef9_row0_col25, #T_e9ef9_row0_col26, #T_e9ef9_row0_col27, #T_e9ef9_row0_col28, #T_e9ef9_row0_col29, #T_e9ef9_row0_col30, #T_e9ef9_row1_col4, #T_e9ef9_row1_col5, #T_e9ef9_row1_col6, #T_e9ef9_row1_col7, #T_e9ef9_row1_col8, #T_e9ef9_row1_col9, #T_e9ef9_row1_col10, #T_e9ef9_row1_col11, #T_e9ef9_row1_col12, #T_e9ef9_row1_col13, #T_e9ef9_row1_col14, #T_e9ef9_row1_col15, #T_e9ef9_row1_col16, #T_e9ef9_row1_col17, #T_e9ef9_row1_col18, #T_e9ef9_row1_col19, #T_e9ef9_row1_col20, #T_e9ef9_row1_col21, #T_e9ef9_row1_col22, #T_e9ef9_row1_col23, #T_e9ef9_row1_col24, #T_e9ef9_row1_col25, #T_e9ef9_row1_col26, #T_e9ef9_row1_col27, #T_e9ef9_row1_col28, #T_e9ef9_row1_col29, #T_e9ef9_row1_col30, #T
#T_c02bc_row6_col6, #T_c02bc_row6_col7, #T_c02bc_row6_col8, #T_c02bc_row6_col9, #T_c02bc_row6_col10, #T_c02bc_row6_col11, #T_c02bc_row6_col12, #T_c02bc_row6_col13, #T_c02bc_row6_col14, #T_c02bc_row6_col15, #T_c02bc_row6_col16, #T_c02bc_row6_col17, #T_c02bc_row6_col18, #T_c02bc_row6_col19, #T_c02bc_row6_col20, #T_c02bc_row6_col21, #T_c02bc_row6_col22, #T_c02bc_row6_col23, #T_c02bc_row6_col24, #T_c02bc_row6_col25, #T_c02bc_row6_col26, #T_c02bc_row6_col27, #T_c02bc_row6_col28, #T_c02bc_row6_col29, #T_c02bc_row6_col30, #T_c02bc_row7_col4, #T_c02bc_row7_col5, #T_c02bc_row7_col6, #T_c02bc_row7 ...

# %%
# Save keras model3 to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model3 = model_to_onnx(model3, framework='keras',
                          transfer_learning=True,
                          deep_learning=True)

with open("model3.onnx", "wb") as f:
    f.write(onnx_model3.SerializeToString())

# %%
# Submit the best three models to the leader board

# Submit Model 3

#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model3.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model3.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 57/57 [==============================] - 0s 2ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 72
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_7e246_row0_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 81.8%, transparent 81.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_7e246_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 81.8%, transparent 81.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_7e246_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 81.8%, transparent 81.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_7e246_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 81.8%, transparent 81.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_7e246_row0_col4, #T_7e246_row0_col5, #T_7e246_row0_col6, #T_7e246_row0_col7, #T_7e246_row0_col8, #T_7e246_row0_col9, #T_7e246_row0_col10, #T_7e246_row0_col11, #T_7e246_row0_col12, #T_7e246_row0_col13, #T_7e246_row0_col14, #T_7e246_row0_col15, #T_7e246_row0_col16, #T_7e246_row0_col17, #T_7e246_row0_col18, #T_7e246_row0_col19, #T_7e246_row0_col20, #T_7e246_row0_col21, #T_7e246_row0_col22, #T_7e246_row0_col23, #T_7e246_row0_col24, #T_7e246_row0_col25, #T_7e246_row0_col26, #T_7e246_row0_col27, #T_7e246_row0_col28, #T_7e246_row0_col29, #T_7e246_row0_col30, #T_7e246_row1_col4, #T_7e246_row1_col5, #T_7e246_row1_col6, #T_7e246_row1_col7, #T_7e246_row1_col8, #T_7e246_row1_col9, #T_7e246_row1_col10, #T_7e246_row1_col11, #T_7e246_row1_col12, #T_7e246_row1_col13, #T_7e246_row1_col14, #T_7e246_row1_col15, #T_7e246_row1_col16, #T_7e246_row1_col17, #T_7e246_row1_col18, #T_7e246_row1_col19, #T_7e246_row1_col20, #T_7e246_row1_col21, #T_7e246_row1_col22, #T_7e246_row1_col23, #T_7e246_row1_col24, #T_7e246_row1_col25, #T_7e246_row1_col26, #T_7e246_row1_col27, #T_7e246_row1_col28, #T_7e246_row1_col29, #T_7e246_row1_col30, #T_7e246_row2_col4, #T_7e246_row2_col5, #T_7e246_row2_col6, #T_7e246_row2_col7, #T_7e246_row2_col8, #T_7e246_row2_col9, #T_7e246_row2_col10, #T_7e246_row2_col11, #T_7e246_row2_col12, #T_7e246_row2_col13, #T_7e246_row2_col14, #T_7e246_row2_col15, #T_7e246_row2_col16, #T_7e246_row2_col17, #T_7e246_row2_col18, #T_7e246_row2_col19, #T_7e246_row2_col20, #T
# %% [markdown]
# **3. After you submit your first three models, describe your best model with your team via your team slack channel**

# %% [markdown]
# * Fit and submit up to three more models after learning from your team.

# %%
# Model 4
from tensorflow.keras.layers import Dense, Embedding, Conv1D, GlobalMaxPooling1D

model4 = Sequential()
model4.add(Embedding(10000, 32, input_length=40))
model4.add(Conv1D(32, 7, activation='relu'))
model4.add(GlobalMaxPooling1D())
model4.add(Dense(2, activation='softmax'))

model4.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history4 = model4.fit(preprocessor(X_train), y_train, epochs=10, batch_size=256, validation_split=0.2)
# Out:
# Epoch 1/10
# 22/22 [==============================] - 1s 34ms/step - loss: 0.6721 - acc: 0.6147 - val_loss: 0.8671 - val_acc: 0.1488
# Epoch 2/10
# 22/22 [==============================] - 1s 26ms/step - loss: 0.6561 - acc: 0.6149 - val_loss: 0.9012 - val_acc: 0.1488
# Epoch 3/10
# 22/22 [==============================] - 1s 29ms/step - loss: 0.6367 - acc: 0.6149 - val_loss: 0.8415 - val_acc: 0.1488
# Epoch 4/10
# 22/22 [==============================] - 1s 27ms/step - loss: 0.5985 - acc: 0.6288 - val_loss: 0.8008 - val_acc: 0.2233
# Epoch 5/10
# 22/22 [==============================] - 1s 26ms/step - loss: 0.5385 - acc: 0.7294 - val_loss: 0.7312 - val_acc: 0.4646
# Epoch 6/10
# 22/22 [==============================] - 1s 27ms/step - loss: 0.4644 - acc: 0.8295 - val_loss: 0.6631 - val_acc: 0.6134
# Epoch 7/10
# 22/22 [==============================] - 1s 27ms/step - loss: 0.3895 - acc: 0.8815 - val_loss: 0.6634 - val_acc: 0.6272
# Epoch 8/10
# 22/22 [==============================] - 1s 26ms/step - loss: 0.3220 - acc: 0.9070 - val_loss: 0.6007 - val_acc: 0.6821
# Epoch 9/10
# 22/22 [==============================] - 1s 27ms/step - loss: 0.2640 - acc: 0.9258 - val_loss: 0.5982 - val_acc: 0.6929
# Epoch 10/10
# 22/22 [==============================] - 1s 32ms/step - loss: 0.2158 - acc: 0.9393 - val_loss: 0.6189 - val_acc: 0.6951

# %%
# Save keras model3 to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model4 = model_to_onnx(model4, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model4.onnx", "wb") as f:
    f.write(onnx_model4.SerializeToString())

# %%
# Submit Model 4

#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=model4.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model4.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 57/57 [==============================] - 0s 2ms/step
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 73
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:2763

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_5d03e_row0_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 81.8%, transparent 81.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_5d03e_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 81.8%, transparent 81.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_5d03e_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 81.8%, transparent 81.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_5d03e_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 81.8%, transparent 81.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_5d03e_row0_col4, #T_5d03e_row0_col5, #T_5d03e_row0_col6, #T_5d03e_row0_col7, #T_5d03e_row0_col8, #T_5d03e_row0_col9, #T_5d03e_row0_col10, #T_5d03e_row0_col11, #T_5d03e_row0_col12, #T_5d03e_row0_col13, #T_5d03e_row0_col14, #T_5d03e_row0_col15, #T_5d03e_row0_col16, #T_5d03e_row0_col17, #T_5d03e_row0_col18, #T_5d03e_row0_col19, #T_5d03e_row0_col20, #T_5d03e_row0_col21, #T_5d03e_row0_col22, #T_5d03e_row0_col23, #T_5d03e_row0_col24, #T_5d03e_row0_col25, #T_5d03e_row0_col26, #T_5d03e_row0_col27, #T_5d03e_row0_col28, #T_5d03e_row0_col29, #T_5d03e_row0_col30, #T_5d03e_row
e_row4_col30, #T_5d03e_row5_col4, #T_5d03e_row5_col5, #T_5d03e_row5_col6, #T_5d03e_row5_col7, #T_5d03e_row5_col8, #T_5d03e_row5_col9, #T_5d03e_row5_col10, #T_5d03e_row5_col11, #T_5d03e_row5_col12, #T_5d03e_row5_col13, #T_5d03e_row5_col14, #T_5d03e_row5_col15, #T_5d03e_row5_col16, #T_5d03e_row5_col17, #T_5d03e_row5_col18, #T_5d03e_row5_col19, #T_5d03e_row5_col20, #T_5d03e_row5_col21, #T_5d03e_row5_col22, #T_5d03e_row5_col23, #T_5d03e_row5_col24, #T_5d03e_row5_col25, #T_5d03e_row5_col26, #T_5d03e_row5_col27, #T_5d03e_row5_col28, #T_5d03e_row5_col29, #T_5d03e_row5_col30, #T_5d03e_row6_col4, #T_5d03e_row6_col5, #T_5d03e_row6_col6, #T_5d03e_row6_col7, #T_5d03e_row6_col8, #T_5d03e_row6_col9, #T_5d03e_row6_col10, #T_5d03e_row6_col11, #T_5d03e_row6_col12, #T_5d03e_row6_col13, #T_5d03e_row6_col14, #T_5d03e_row6_col15, #T_5d03e_row6_col16, #T_5d03e_row6_col17, #T_5d03e_row6_col18, #T_5d03e_row6_col19, #T_5d03e_row6_col20, #T_5d03e_row6_col21, #T_5d03e_row6_col22, #T_5d03e_row6_col23, #T_5d03e_row6_col24, #T_5d03e_row6_col25, #T_5d03e_row6_col26, #T_5d03e_row6_col27, #T_5d03e_row6_col28, #T_5d03e_row6_col29, #T_5d03e_row6_col30, #T_5d03e_row7_col4, #T_5d03e_row7_col5, #T_5d03e_row7_col6, #T_5d03e_row7 ...

# %% [markdown]
# # **Discuss results**

# %% [markdown]
# Model4 is #12 on the leaderboard. So far, Model2 performs the best.

# %% [markdown]
# # **4. Discuss which models you tried and which models performed better and point out relevant hyper-parameter values for successful models.**

# %% [markdown]
# I tried 4 models in total. Model1 uses an Embedding layer and LSTM layers. Model2 uses an Embedding layer and Conv1d layers. Model3 uses transfer learning with glove embeddings. Model4 is created based on Model2 and the discussion results with the group. Among them, Model2 performs the best, with the following hyper-parameter values:
#
# *   **Embedding Dimension**: The embedding layer in the model defines the dimension of the dense embedding vectors used to represent each word in the input text. In this case, the embedding dimension is set to 32.
#
# *   **Filter Size**: The Conv1D layer in the model uses a kernel of size 7 to perform convolution on the input sequence.
#
# *   **Number of Filters**: The Conv1D layer in the model uses 32 filters to generate 32 feature maps.
#
# *   **Pooling Method**: The GlobalMaxPooling1D layer in the model performs global max pooling on the feature maps generated by the Conv1D layer.
#
# *   **Number of Hidden Units**: The Dense layer in the model has 2 hidden units.
#
# *   **Learning Rate**: The learning rate is a hyperparameter that controls the step size of the optimizer during training. In this case, the optimizer is RMSprop, which has a default learning rate of 0.001.
#
# *   **Batch Size**: The batch size is the number of samples that are processed before the model is updated during training. In this case, the batch size is set to 128.
#
# *   **Number of Epochs**: The number of epochs is the number of times the model is trained on the entire dataset. In this case, the model is trained for 10 epochs.
